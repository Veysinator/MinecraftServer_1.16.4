# %% [markdown]
# <a href="https://colab.research.google.com/github/Veysinator/MinecraftServer_1.16.4/blob/main/boinc_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install boinc
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   boinc-client boinc-manager libboinc7 libwxbase3.0-0v5
#   libwxgtk-webview3.0-gtk3-0v5 libwxgtk3.0-gtk3-0v5
# Suggested packages:
#   boinc-client-opencl boinc-client-nvidia-cuda libgl1-mesa-glx
# The following NEW packages will be installed:
#   boinc boinc-client boinc-manager libboinc7 libwxbase3.0-0v5
#   libwxgtk-webview3.0-gtk3-0v5 libwxgtk3.0-gtk3-0v5
# 0 upgraded, 7 newly installed, 0 to remove and 21 not upgraded.
# Need to get 7,758 kB of archives.
# After this operation, 31.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 libboinc7 amd64 7.16.6+dfsg-1 [396 kB]
# ...

# %%
# !tmux new-session -d -s boinc

# %%
# !tmux send-keys 'boinc' C-m

# %%
# !boinccmd --lookup_account URL USERNAME PASSWORD

# eg URL = http://einstein.phys.uwm.edu/
# with your einstein@home username and password
# this cell prints your ACCOUNT_ID

# %%
# this cell downloads tasks and starts running them!
# copy over the URL you used in the last cell and ACCOUNT_ID produced by last cell

# !boinccmd --project_attach https://milkyway.cs.rpi.edu/milkyway/ 331874fb0a5333951bc8bc4fa14a2c5a

# %%
# get status of tasks with --get_state or --get_tasks

# !boinccmd --get_tasks
# Out:
# ======== Tasks ========
# 1) -----------
#    name: de_modfit_70_bundle5_3s_south_pt2_4_1674667491_35334376_0
#    WU name: de_modfit_70_bundle5_3s_south_pt2_4_1674667491_35334376
#    project URL: https://milkyway.cs.rpi.edu/milkyway/
#    received: Sat Feb 18 16:42:55 2023
#    report deadline: Thu Mar  2 16:42:55 2023
#    ready to report: no
#    state: downloaded
#    scheduler state: scheduled
#    active_task_state: EXECUTING
#    app version num: 146
#    resources: 0.995 CPUs + 1 NVIDIA GPU
#    estimated CPU time remaining: 88.131460
#    slot: 1
#    PID: 2858
#    CPU time at last checkpoint: 0.000000
#    current CPU time: 12.294550
#    fraction done: 0.068125
#    swap size: 4925 MB
#    working set size: 136 MB
# 2) -----------
#    name: de_modfit_80_bundle5_3s_south_pt2_4_1674667491_35128519_1
#    WU name: de_modfit_80_bundle5_3s_south_pt2_4_1674667491_35128519
#    project URL: https://milkyway.cs.rpi.edu/milkyway/
#    received: Sat Feb 18 16:44:34 2023
# ...

# %%
# !boinccmd --project https://milkyway.cs.rpi.edu/milkyway/ update

# %%
# !boinccmd --task https://milkyway.cs.rpi.edu/milkyway/  resume

# %%
# !boinccmd --set_gpu_mode always
